# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import matplotlib.pyplot as plt
# %matplotlib inline


# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: Earlystop
"""
from keras.callbacks import EarlyStopping
EARLY_STOPS_COUNT = [10, 25]
EARLY_STOPS = []
for earlystopcnt in EARLY_STOPS_COUNT:
    earlystop = EarlyStopping(monitor="val_loss", 
                          patience=earlystopcnt,
                          verbose=1
                          )
    EARLY_STOPS.append([earlystop, earlystopcnt])
print(EARLY_STOPS)
# Out:
# [[<keras.callbacks.callbacks.EarlyStopping object at 0x000000001EFF8608>, 10], [<keras.callbacks.callbacks.EarlyStopping object at 0x000000001EFFBC08>, 25]]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
import keras.backend as K

"""
以迴圈方式遍歷組合來訓練模型
"""
for [earlystop, cnt] in EARLY_STOPS:
    K.clear_session()
    print("early stop patience: {}".format(cnt))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              callbacks=[earlystop]              ,
              shuffle=True)
    
    # Collect results
    exp_name_tag = ("exp-%s" % (cnt))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
# early stop patience: 10
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 7s 146us/step - loss: 2.2122 - accuracy: 0.2652 - val_loss: 2.1202 - val_accuracy: 0.2075
# Epoch 2/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.7445 - accuracy: 0.3914 - val_loss: 1.9453 - val_accuracy: 0.3010
# Epoch 3/50
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.6185 - accuracy: 0.4343 - val_loss: 1.8104 - val_accuracy: 0.3679
# Epoch 4/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.5458 - accuracy: 0.4616 - val_loss: 1.7032 - val_accuracy: 0.4084
# Epoch 5/50
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.4891 - accuracy: 0.4811 - val_loss: 1.6277 - val_accuracy: 0.4293
# Epoch 6/50
# 50000/50000 [==============================] - 6s 129us/step - loss: 1.4434 - accuracy: 0.4973 - val_loss: 1.5823 - val_accuracy: 0.4411
# Epoch 7/50
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.4050 - accuracy: 0.5105 - val_loss: 1.5496 - val_accuracy: 0.4544
# Epoch 8/50
# 50000/50000 [==============================] - 7s 134us/step - loss: 1.3682 - accuracy: 0.5253 - val_loss: 1.5297 - val_accuracy: 0.4579
# Epoch 9/50
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.3366 - accuracy: 0.5351 - val_loss: 1.5026 - val_accuracy: 0.4727
# Epoch 10/50
# 50000/50000 [==============================] - 7s 140us/step - loss: 1.3083 - accuracy: 0.5464 - val_loss: 1.4970 - val_accuracy: 0.4698
# Epoch 11/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.2792 - accuracy: 0.5564 - val_loss: 1.4824 - val_accuracy: 0.4747
# Epoch 12/50
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.2526 - accuracy: 0.5650 - val_loss: 1.4767 - val_accuracy: 0.4779
# Epoch 13/50
# 50000/50000 [==============================] - 7s 145us/step - loss: 1.2275 - accuracy: 0.5746 - val_loss: 1.4851 - val_accuracy: 0.4724
# Epoch 14/50
# 50000/50000 [==============================] - 7s 147us/step - loss: 1.2031 - accuracy: 0.5830 - val_loss: 1.4680 - val_accuracy: 0.4815
# Epoch 15/50
# 50000/50000 [==============================] - 7s 148us/step - loss: 1.1807 - accuracy: 0.5905 - val_loss: 1.4623 - val_accuracy: 0.4829
# Epoch 16/50
# 50000/50000 [==============================] - 7s 150us/step - loss: 1.1562 - accuracy: 0.6020 - val_loss: 1.4623 - val_accuracy: 0.4864
# Epoch 17/50
# 50000/50000 [==============================] - 8s 152us/step - loss: 1.1336 - accuracy: 0.6100 - val_loss: 1.4625 - val_accuracy: 0.4809
# Epoch 18/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.1129 - accuracy: 0.6181 - val_loss: 1.4546 - val_accuracy: 0.4863
# Epoch 19/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.0929 - accuracy: 0.6253 - val_loss: 1.4527 - val_accuracy: 0.4936
# Epoch 20/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.0700 - accuracy: 0.6336 - val_loss: 1.4570 - val_accuracy: 0.4856
# Epoch 21/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 1.0485 - accuracy: 0.6437 - val_loss: 1.4751 - val_accuracy: 0.4778
# Epoch 22/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.0289 - accuracy: 0.6511 - val_loss: 1.4540 - val_accuracy: 0.4909
# Epoch 23/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.0076 - accuracy: 0.6583 - val_loss: 1.4681 - val_accuracy: 0.4837
# Epoch 24/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 0.9875 - accuracy: 0.6669 - val_loss: 1.4835 - val_accuracy: 0.4826
# Epoch 25/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 0.9686 - accuracy: 0.6735 - val_loss: 1.4685 - val_accuracy: 0.4891
# Epoch 26/50
# 50000/50000 [==============================] - 8s 155us/step - loss: 0.9480 - accuracy: 0.6822 - val_loss: 1.4749 - val_accuracy: 0.4869
# Epoch 27/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 0.9279 - accuracy: 0.6888 - val_loss: 1.4698 - val_accuracy: 0.4880
# Epoch 28/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 0.9097 - accuracy: 0.6961 - val_loss: 1.4673 - val_accuracy: 0.4946
# Epoch 29/50
# 50000/50000 [==============================] - 8s 153us/step - loss: 0.8887 - accuracy: 0.7049 - val_loss: 1.4828 - val_accuracy: 0.4882
# Epoch 00029: early stopping
# early stop patience: 25
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 2.1955 - accuracy: 0.2760 - val_loss: 2.1075 - val_accuracy: 0.2405
# Epoch 2/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.7349 - accuracy: 0.3982 - val_loss: 1.9649 - val_accuracy: 0.3091
# Epoch 3/50
# 50000/50000 [==============================] - 8s 154us/step - loss: 1.6138 - accuracy: 0.4373 - val_loss: 1.8244 - val_accuracy: 0.3683
# Epoch 4/50
# 50000/50000 [==============================] - 8s 157us/step - loss: 1.5415 - accuracy: 0.4610 - val_loss: 1.7224 - val_accuracy: 0.4030
# Epoch 5/50
# 50000/50000 [==============================] - 8s 156us/step - loss: 1.4848 - accuracy: 0.4806 - val_loss: 1.6468 - val_accuracy: 0.4286
# Epoch 6/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.4401 - accuracy: 0.4975 - val_loss: 1.5828 - val_accuracy: 0.4518
# Epoch 7/50
# 50000/50000 [==============================] - 8s 163us/step - loss: 1.3998 - accuracy: 0.5119 - val_loss: 1.5504 - val_accuracy: 0.4505
# Epoch 8/50
# 50000/50000 [==============================] - 8s 163us/step - loss: 1.3636 - accuracy: 0.5246 - val_loss: 1.5166 - val_accuracy: 0.4618
# Epoch 9/50
# 50000/50000 [==============================] - 8s 161us/step - loss: 1.3311 - accuracy: 0.5376 - val_loss: 1.5084 - val_accuracy: 0.4673
# Epoch 10/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 1.3025 - accuracy: 0.5469 - val_loss: 1.4928 - val_accuracy: 0.4730
# Epoch 11/50
# 50000/50000 [==============================] - 8s 156us/step - loss: 1.2725 - accuracy: 0.5581 - val_loss: 1.5027 - val_accuracy: 0.4641
# Epoch 12/50
# 50000/50000 [==============================] - 8s 164us/step - loss: 1.2467 - accuracy: 0.5683 - val_loss: 1.4702 - val_accuracy: 0.4803
# Epoch 13/50
# 50000/50000 [==============================] - 8s 160us/step - loss: 1.2212 - accuracy: 0.5773 - val_loss: 1.4642 - val_accuracy: 0.4829
# Epoch 14/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.1973 - accuracy: 0.5853 - val_loss: 1.4681 - val_accuracy: 0.4795
# Epoch 15/50
# 50000/50000 [==============================] - 8s 161us/step - loss: 1.1729 - accuracy: 0.5947 - val_loss: 1.4751 - val_accuracy: 0.4818
# Epoch 16/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.1491 - accuracy: 0.6046 - val_loss: 1.4520 - val_accuracy: 0.4886
# Epoch 17/50
# 50000/50000 [==============================] - 8s 160us/step - loss: 1.1245 - accuracy: 0.6138 - val_loss: 1.4542 - val_accuracy: 0.4870
# Epoch 18/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.1055 - accuracy: 0.6212 - val_loss: 1.4556 - val_accuracy: 0.4897
# Epoch 19/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.0805 - accuracy: 0.6289 - val_loss: 1.4543 - val_accuracy: 0.4867
# Epoch 20/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.0591 - accuracy: 0.6380 - val_loss: 1.4540 - val_accuracy: 0.4898
# Epoch 21/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 1.0379 - accuracy: 0.6455 - val_loss: 1.4664 - val_accuracy: 0.4885
# Epoch 22/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 1.0159 - accuracy: 0.6561 - val_loss: 1.4544 - val_accuracy: 0.4828
# Epoch 23/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.9967 - accuracy: 0.6618 - val_loss: 1.4670 - val_accuracy: 0.4900
# Epoch 24/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.9738 - accuracy: 0.6715 - val_loss: 1.4523 - val_accuracy: 0.4932
# Epoch 25/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 0.9546 - accuracy: 0.6778 - val_loss: 1.4667 - val_accuracy: 0.4870
# Epoch 26/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 0.9353 - accuracy: 0.6853 - val_loss: 1.4729 - val_accuracy: 0.4925
# Epoch 27/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 0.9133 - accuracy: 0.6946 - val_loss: 1.4619 - val_accuracy: 0.4970
# Epoch 28/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.8929 - accuracy: 0.7027 - val_loss: 1.4680 - val_accuracy: 0.4940
# Epoch 29/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.8739 - accuracy: 0.7103 - val_loss: 1.4749 - val_accuracy: 0.4943
# Epoch 30/50
# 50000/50000 [==============================] - 8s 163us/step - loss: 0.8529 - accuracy: 0.7187 - val_loss: 1.4931 - val_accuracy: 0.4920
# Epoch 31/50
# 50000/50000 [==============================] - 8s 160us/step - loss: 0.8340 - accuracy: 0.7267 - val_loss: 1.4911 - val_accuracy: 0.4891
# Epoch 32/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.8141 - accuracy: 0.7338 - val_loss: 1.4955 - val_accuracy: 0.4993
# Epoch 33/50
# 50000/50000 [==============================] - 8s 164us/step - loss: 0.7936 - accuracy: 0.7415 - val_loss: 1.4900 - val_accuracy: 0.4987
# Epoch 34/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.7736 - accuracy: 0.7507 - val_loss: 1.5001 - val_accuracy: 0.4962
# Epoch 35/50
# 50000/50000 [==============================] - 8s 163us/step - loss: 0.7548 - accuracy: 0.7597 - val_loss: 1.5211 - val_accuracy: 0.4928
# Epoch 36/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.7359 - accuracy: 0.7652 - val_loss: 1.5246 - val_accuracy: 0.4935
# Epoch 37/50
# 50000/50000 [==============================] - 8s 161us/step - loss: 0.7162 - accuracy: 0.7739 - val_loss: 1.5269 - val_accuracy: 0.4943
# Epoch 38/50
# 50000/50000 [==============================] - 8s 165us/step - loss: 0.6953 - accuracy: 0.7825 - val_loss: 1.5308 - val_accuracy: 0.4995
# Epoch 39/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.6785 - accuracy: 0.7882 - val_loss: 1.5339 - val_accuracy: 0.4955
# Epoch 40/50
# 50000/50000 [==============================] - 8s 159us/step - loss: 0.6590 - accuracy: 0.7961 - val_loss: 1.5612 - val_accuracy: 0.4890
# Epoch 41/50
# 50000/50000 [==============================] - 8s 158us/step - loss: 0.6430 - accuracy: 0.8027 - val_loss: 1.5726 - val_accuracy: 0.4878
# Epoch 00041: early stopping

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
